# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
# Load fused embeddings
fused = np.load('fused_x75ktrain.npy')
print("Original shape:", fused.shape)
# Out:
# Original shape: (75000, 512)

# %%
# Apply PCA for dimensionality reduction
pca = PCA(n_components=256, random_state=42)
fused_reduced = pca.fit_transform(fused)

print("Reduced shape:", fused_reduced.shape)

# Save reduced embeddings
np.save('fused_x_reduced_image.npy', fused_reduced)
print("Saved reduced embeddings as 'fused_x_reduced.npy'")
# Out:
# Reduced shape: (75000, 256)
# Saved reduced embeddings as 'fused_x_reduced.npy'

# %%
import os
from pathlib import Path
from typing import List


import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import joblib

# XGBoost import
from xgboost import XGBRegressor

# %%
def smape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    # avoid division by zero
    mask = denominator != 0
    smape_value = np.mean(np.abs(y_true[mask] - y_pred[mask]) / denominator[mask]) * 100
    return smape_value

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib
import numpy as np
import os

def train_and_evaluate(X: np.ndarray, y: np.ndarray, out_dir: str = 'outputs', seed: int = 42):
    os.makedirs(out_dir, exist_ok=True)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # XGBoost regressor with training progress
    model = XGBRegressor(
        n_estimators=2000,
        max_depth=6,
        learning_rate=0.04,
        subsample=0.8,
        colsample_bytree=0.8,
        min_child_weight=3,
        gamma=0.1,
        reg_alpha=0.01,
        reg_lambda=1,
        random_state=seed,
        n_jobs=-1,
        verbosity=1,
        eval_metric="rmse"
    )

    model.fit(
        X_train_scaled, y_train,
        eval_set=[(X_train_scaled, y_train), (X_test_scaled, y_test)],
        verbose=10
    )

    y_pred = model.predict(X_test_scaled)

    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    smape_val = smape(y_test, y_pred)  # make sure you have defined smape()

    print("\nEvaluation on test set:")
    print(f"MAE: {mae:.6f}")
    print(f"RMSE: {rmse:.6f}")
    print(f"R2: {r2:.6f}")
    print(f"SMAPE: {smape_val:.2f}%")

    # save model + scaler
    joblib.dump(model, os.path.join(out_dir, 'xgb_regressor.joblib'))
    joblib.dump(scaler, os.path.join(out_dir, 'scaler.joblib'))

    # save predictions and true values
    np.save(os.path.join(out_dir, 'y_test.npy'), y_test)
    np.save(os.path.join(out_dir, 'y_pred.npy'), y_pred)

    print(f"Saved model and scaler to {out_dir}")
    return {'mae': mae, 'rmse': rmse, 'r2': r2}

# %%
out_dir = 'outputs'
seed = 42

# %%
csv_file = 'catalog_75ktrain.csv'

# %%
df = pd.read_csv(csv_file, on_bad_lines='skip')

# %%
 # save target vector y (price_log)
y = df['price_log'].values.astype(float)

# %%
y.shape
# Out:
# (75000,)

# %%
fuse = np.load('fused_x_reduced_image.npy')

# %%
metrics = train_and_evaluate(fuse, y, out_dir=out_dir, seed=seed)
# Out:
# [0]	validation_0-rmse:0.93468	validation_1-rmse:0.94764
# [10]	validation_0-rmse:0.89533	validation_1-rmse:0.91259
# [20]	validation_0-rmse:0.86931	validation_1-rmse:0.89079
# [30]	validation_0-rmse:0.84964	validation_1-rmse:0.87547
# [40]	validation_0-rmse:0.83389	validation_1-rmse:0.86359
# [50]	validation_0-rmse:0.82082	validation_1-rmse:0.85450
# [60]	validation_0-rmse:0.80980	validation_1-rmse:0.84760
# [70]	validation_0-rmse:0.79975	validation_1-rmse:0.84197
# [80]	validation_0-rmse:0.79062	validation_1-rmse:0.83701
# [90]	validation_0-rmse:0.78199	validation_1-rmse:0.83259
# [100]	validation_0-rmse:0.77390	validation_1-rmse:0.82860
# [110]	validation_0-rmse:0.76620	validation_1-rmse:0.82477
# [120]	validation_0-rmse:0.75885	validation_1-rmse:0.82152
# [130]	validation_0-rmse:0.75179	validation_1-rmse:0.81846
# [140]	validation_0-rmse:0.74523	validation_1-rmse:0.81568
# [150]	validation_0-rmse:0.73888	validation_1-rmse:0.81295
# [160]	validation_0-rmse:0.73251	validation_1-rmse:0.81057
# [170]	validation_0-rmse:0.72652	validation_1-rmse:0.80842
# [180]	validation_0-rmse:0.72076	validation_1-rmse:0.80616
# [190]	validation_0-rmse:0.71523	validation_1-rmse:0.80412
# [200]	validation_0-rmse:0.70985	validation_1-rmse:0.80250
# [210]	validation_0-rmse:0.70474	validation_1-rmse:0.80092
# [220]	validation_0-rmse:0.69965	validation_1-rmse:0.79931
# [230]	validation_0-rmse:0.69448	validation_1-rmse:0.79764
# [240]	validation_0-rmse:0.68953	validation_1-rmse:0.79601
# [250]	validation_0-rmse:0.68481	validation_1-rmse:0.79446
# [260]	validation_0-rmse:0.68012	validation_1-rmse:0.79298
# [270]	validation_0-rmse:0.67552	validation_1-rmse:0.79166
# [280]	validation_0-rmse:0.67122	validation_1-rmse:0.79033
# [290]	validation_0-rmse:0.66684	validation_1-rmse:0.78914
# [300]	validation_0-rmse:0.66242	validation_1-rmse:0.78817
# [310]	validation_0-rmse:0.65811	validation_1-rmse:0.78700
# [320]	validation_0-rmse:0.65407	validation_1-rmse:0.78597
# [330]	validation_0-rmse:0.65006	validation_1-rmse:0.78494
# [340]	validation_0-rmse:0.64595	validation_1-rmse:0.78386
# [350]	validation_0-rmse:0.64198	validation_1-rmse:0.78287
# [360]	validation_0-rmse:0.63825	validation_1-rmse:0.78210
# [370]	validation_0-rmse:0.63452	validation_1-rmse:0.78132
# [380]	validation_0-rmse:0.63096	validation_1-rmse:0.78055
# [390]	validation_0-rmse:0.62748	validation_1-rmse:0.77981
# [400]	validation_0-rmse:0.62408	validation_1-rmse:0.77906
# [410]	validation_0-rmse:0.62052	validation_1-rmse:0.77832
# [420]	validation_0-rmse:0.61699	validation_1-rmse:0.77754
# [430]	validation_0-rmse:0.61351	validation_1-rmse:0.77693
# [440]	validation_0-rmse:0.61015	validation_1-rmse:0.77628
# [450]	validation_0-rmse:0.60686	validation_1-rmse:0.77573
# [460]	validation_0-rmse:0.60381	validation_1-rmse:0.77526
# [470]	validation_0-rmse:0.60070	validation_1-rmse:0.77459
# [480]	validation_0-rmse:0.59761	validation_1-rmse:0.77409
# [490]	validation_0-rmse:0.59439	validation_1-rmse:0.77358
# [500]	validation_0-rmse:0.59129	validation_1-rmse:0.77307
# [510]	validation_0-rmse:0.58832	validation_1-rmse:0.77240
# [520]	validation_0-rmse:0.58525	validation_1-rmse:0.77182
# [530]	validation_0-rmse:0.58220	validation_1-rmse:0.77144
# [540]	validation_0-rmse:0.57951	validation_1-rmse:0.77089
# [550]	validation_0-rmse:0.57677	validation_1-rmse:0.77037
# [560]	validation_0-rmse:0.57397	validation_1-rmse:0.76978
# [570]	validation_0-rmse:0.57149	validation_1-rmse:0.76939
# [580]	validation_0-rmse:0.56903	validation_1-rmse:0.76907
# [590]	validation_0-rmse:0.56618	validation_1-rmse:0.76871
# [600]	validation_0-rmse:0.56370	validation_1-rmse:0.76836
# [610]	validation_0-rmse:0.56118	validation_1-rmse:0.76799
# [620]	validation_0-rmse:0.55873	validation_1-rmse:0.76755
# [630]	validation_0-rmse:0.55627	validation_1-rmse:0.76711
# [640]	validation_0-rmse:0.55375	validation_1-rmse:0.76683
# [650]	validation_0-rmse:0.55098	validation_1-rmse:0.76644
# [660]	validation_0-rmse:0.54834	validation_1-rmse:0.76604
# [670]	validation_0-rmse:0.54596	validation_1-rmse:0.76572
# [680]	validation_0-rmse:0.54346	validation_1-rmse:0.76540
# [690]	validation_0-rmse:0.54108	validation_1-rmse:0.76517
# [700]	validation_0-rmse:0.53870	validation_1-rmse:0.76480
# [710]	validation_0-rmse:0.53646	validation_1-rmse:0.76457
# [720]	validation_0-rmse:0.53383	validation_1-rmse:0.76409
# [730]	validation_0-rmse:0.53148	validation_1-rmse:0.76381
# [740]	validation_0-rmse:0.52927	validation_1-rmse:0.76352
# [750]	validation_0-rmse:0.52677	validation_1-rmse:0.76315
# [760]	validation_0-rmse:0.52466	validation_1-rmse:0.76294
# [770]	validation_0-rmse:0.52281	validation_1-rmse:0.76274
# [780]	validation_0-rmse:0.52068	validation_1-rmse:0.76238
# [790]	validation_0-rmse:0.51847	validation_1-rmse:0.76217
# [800]	validation_0-rmse:0.51626	validation_1-rmse:0.76197
# [810]	validation_0-rmse:0.51426	validation_1-rmse:0.76170
# [820]	validation_0-rmse:0.51205	validation_1-rmse:0.76153
# [830]	validation_0-rmse:0.51020	validation_1-rmse:0.76134
# [840]	validation_0-rmse:0.50806	validation_1-rmse:0.76110
# [850]	validation_0-rmse:0.50601	validation_1-rmse:0.76092
# [860]	validation_0-rmse:0.50374	validation_1-rmse:0.76068
# [870]	validation_0-rmse:0.50184	validation_1-rmse:0.76044
# [880]	validation_0-rmse:0.49954	validation_1-rmse:0.76027
# [890]	validation_0-rmse:0.49759	validation_1-rmse:0.76015
# [900]	validation_0-rmse:0.49562	validation_1-rmse:0.76000
# [910]	validation_0-rmse:0.49355	validation_1-rmse:0.75982
# [920]	validation_0-rmse:0.49163	validation_1-rmse:0.75960
# [930]	validation_0-rmse:0.48964	validation_1-rmse:0.75943
# [940]	validation_0-rmse:0.48756	validation_1-rmse:0.75914
# [950]	validation_0-rmse:0.48554	validation_1-rmse:0.75898
# [960]	validation_0-rmse:0.48351	validation_1-rmse:0.75878
# [970]	validation_0-rmse:0.48168	validation_1-rmse:0.75866
# [980]	validation_0-rmse:0.47997	validation_1-rmse:0.75858
# [990]	validation_0-rmse:0.47805	validation_1-rmse:0.75837
# [1000]	validation_0-rmse:0.47611	validation_1-rmse:0.75813
# [1010]	validation_0-rmse:0.47417	validation_1-rmse:0.75801
# [1020]	validation_0-rmse:0.47214	validation_1-rmse:0.75782
# [1030]	validation_0-rmse:0.47026	validation_1-rmse:0.75768
# [1040]	validation_0-rmse:0.46852	validation_1-rmse:0.75756
# [1050]	validation_0-rmse:0.46678	validation_1-rmse:0.75740
# [1060]	validation_0-rmse:0.46486	validation_1-rmse:0.75724
# [1070]	validation_0-rmse:0.46306	validation_1-rmse:0.75706
# [1080]	validation_0-rmse:0.46133	validation_1-rmse:0.75688
# [1090]	validation_0-rmse:0.45972	validation_1-rmse:0.75680
# [1100]	validation_0-rmse:0.45781	validation_1-rmse:0.75667
# [1110]	validation_0-rmse:0.45594	validation_1-rmse:0.75649
# [1120]	validation_0-rmse:0.45408	validation_1-rmse:0.75637
# [1130]	validation_0-rmse:0.45241	validation_1-rmse:0.75627
# [1140]	validation_0-rmse:0.45084	validation_1-rmse:0.75613
# [1150]	validation_0-rmse:0.44899	validation_1-rmse:0.75600
# [1160]	validation_0-rmse:0.44720	validation_1-rmse:0.75596
# [1170]	validation_0-rmse:0.44541	validation_1-rmse:0.75574
# [1180]	validation_0-rmse:0.44358	validation_1-rmse:0.75550
# [1190]	validation_0-rmse:0.44197	validation_1-rmse:0.75535
# [1200]	validation_0-rmse:0.44032	validation_1-rmse:0.75525
# [1210]	validation_0-rmse:0.43870	validation_1-rmse:0.75519
# [1220]	validation_0-rmse:0.43718	validation_1-rmse:0.75504
# [1230]	validation_0-rmse:0.43537	validation_1-rmse:0.75486
# [1240]	validation_0-rmse:0.43358	validation_1-rmse:0.75478
# [1250]	validation_0-rmse:0.43204	validation_1-rmse:0.75460
# [1260]	validation_0-rmse:0.43049	validation_1-rmse:0.75451
# [1270]	validation_0-rmse:0.42896	validation_1-rmse:0.75442
# [1280]	validation_0-rmse:0.42720	validation_1-rmse:0.75425
# [1290]	validation_0-rmse:0.42550	validation_1-rmse:0.75413
# [1300]	validation_0-rmse:0.42379	validation_1-rmse:0.75407
# [1310]	validation_0-rmse:0.42226	validation_1-rmse:0.75383
# [1320]	validation_0-rmse:0.42060	validation_1-rmse:0.75366
# [1330]	validation_0-rmse:0.41871	validation_1-rmse:0.75356
# [1340]	validation_0-rmse:0.41703	validation_1-rmse:0.75342
# [1350]	validation_0-rmse:0.41558	validation_1-rmse:0.75336
# [1360]	validation_0-rmse:0.41395	validation_1-rmse:0.75326
# [1370]	validation_0-rmse:0.41226	validation_1-rmse:0.75312
# [1380]	validation_0-rmse:0.41070	validation_1-rmse:0.75300
# [1390]	validation_0-rmse:0.40904	validation_1-rmse:0.75293
# [1400]	validation_0-rmse:0.40736	validation_1-rmse:0.75296
# [1410]	validation_0-rmse:0.40554	validation_1-rmse:0.75281
# [1420]	validation_0-rmse:0.40390	validation_1-rmse:0.75266
# [1430]	validation_0-rmse:0.40235	validation_1-rmse:0.75258
# [1440]	validation_0-rmse:0.40084	validation_1-rmse:0.75257
# [1450]	validation_0-rmse:0.39923	validation_1-rmse:0.75248
# [1460]	validation_0-rmse:0.39767	validation_1-rmse:0.75235
# [1470]	validation_0-rmse:0.39625	validation_1-rmse:0.75227
# [1480]	validation_0-rmse:0.39483	validation_1-rmse:0.75222
# [1490]	validation_0-rmse:0.39326	validation_1-rmse:0.75211
# [1500]	validation_0-rmse:0.39160	validation_1-rmse:0.75194
# [1510]	validation_0-rmse:0.39015	validation_1-rmse:0.75189
# [1520]	validation_0-rmse:0.38870	validation_1-rmse:0.75185
# [1530]	validation_0-rmse:0.38705	validation_1-rmse:0.75170
# [1540]	validation_0-rmse:0.38563	validation_1-rmse:0.75163
# [1550]	validation_0-rmse:0.38426	validation_1-rmse:0.75165
# [1560]	validation_0-rmse:0.38294	validation_1-rmse:0.75156
# [1570]	validation_0-rmse:0.38118	validation_1-rmse:0.75143
# [1580]	validation_0-rmse:0.37977	validation_1-rmse:0.75132
# [1590]	validation_0-rmse:0.37839	validation_1-rmse:0.75121
# [1600]	validation_0-rmse:0.37689	validation_1-rmse:0.75120
# [1610]	validation_0-rmse:0.37539	validation_1-rmse:0.75116
# [1620]	validation_0-rmse:0.37392	validation_1-rmse:0.75110
# [1630]	validation_0-rmse:0.37241	validation_1-rmse:0.75108
# [1640]	validation_0-rmse:0.37090	validation_1-rmse:0.75096
# [1650]	validation_0-rmse:0.36945	validation_1-rmse:0.75084
# [1660]	validation_0-rmse:0.36803	validation_1-rmse:0.75077
# [1670]	validation_0-rmse:0.36645	validation_1-rmse:0.75070
# [1680]	validation_0-rmse:0.36504	validation_1-rmse:0.75063
# [1690]	validation_0-rmse:0.36348	validation_1-rmse:0.75058
# [1700]	validation_0-rmse:0.36214	validation_1-rmse:0.75052
# [1710]	validation_0-rmse:0.36082	validation_1-rmse:0.75048
# [1720]	validation_0-rmse:0.35929	validation_1-rmse:0.75034
# [1730]	validation_0-rmse:0.35789	validation_1-rmse:0.75030
# [1740]	validation_0-rmse:0.35656	validation_1-rmse:0.75021
# [1750]	validation_0-rmse:0.35515	validation_1-rmse:0.75007
# [1760]	validation_0-rmse:0.35384	validation_1-rmse:0.75011
# [1770]	validation_0-rmse:0.35228	validation_1-rmse:0.75003
# [1780]	validation_0-rmse:0.35087	validation_1-rmse:0.74997
# [1790]	validation_0-rmse:0.34963	validation_1-rmse:0.74993
# [1800]	validation_0-rmse:0.34813	validation_1-rmse:0.74985
# [1810]	validation_0-rmse:0.34681	validation_1-rmse:0.74982
# [1820]	validation_0-rmse:0.34551	validation_1-rmse:0.74977
# [1830]	validation_0-rmse:0.34415	validation_1-rmse:0.74964
# [1840]	validation_0-rmse:0.34279	validation_1-rmse:0.74958
# [1850]	validation_0-rmse:0.34147	validation_1-rmse:0.74953
# [1860]	validation_0-rmse:0.34009	validation_1-rmse:0.74944
# [1870]	validation_0-rmse:0.33877	validation_1-rmse:0.74940
# [1880]	validation_0-rmse:0.33756	validation_1-rmse:0.74934
# [1890]	validation_0-rmse:0.33619	validation_1-rmse:0.74929
# [1900]	validation_0-rmse:0.33484	validation_1-rmse:0.74923
# [1910]	validation_0-rmse:0.33355	validation_1-rmse:0.74919
# [1920]	validation_0-rmse:0.33231	validation_1-rmse:0.74914
# [1930]	validation_0-rmse:0.33106	validation_1-rmse:0.74909
# [1940]	validation_0-rmse:0.32991	validation_1-rmse:0.74916
# [1950]	validation_0-rmse:0.32866	validation_1-rmse:0.74913
# [1960]	validation_0-rmse:0.32728	validation_1-rmse:0.74906
# [1970]	validation_0-rmse:0.32602	validation_1-rmse:0.74900
# [1980]	validation_0-rmse:0.32467	validation_1-rmse:0.74891
# [1990]	validation_0-rmse:0.32365	validation_1-rmse:0.74886
# [1999]	validation_0-rmse:0.32248	validation_1-rmse:0.74882
#
# Evaluation on test set:
# MAE: 0.583871
# RMSE: 0.748815
# R2: 0.381332
# SMAPE: 22.95%
# Saved model and scaler to outputs
